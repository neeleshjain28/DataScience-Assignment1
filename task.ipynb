# %%
salary = int(input("Enter your salary: "))

if salary < 25000:
    print("Still middle class 😭")
else:
    print(" oo teri rahees Party kaha hai 🥳")

# %%
mood = input("Enter girlfriend mood: ")

if mood == "angry":
    print("Run bro 🏃‍♂️")
else:
    print("Safe zone 💖")

# %%
battery = int(input("Enter phone battery percentage: "))

if battery < 20:
    print("Low Battery! Charge before your phone faints 😴📱")
else:
    print("Relax, phone is alive 😎")

# %%
attendance = int(input("Enter your attendance percentage: "))

if attendance >= 75:
    print("You may sit in the exam 😌")
else:
    print("Meet HOD immediately 😐")

# %%
love = input("Do you love Maggi? (yes/no): ")

if love == "yes":
    print("True Maggi Fan 🍜")
else:
    print("You are adopted 😜")
