# %% [markdown]
# 🔒 Encapsulation – Definition
#
# Encapsulation is an OOP concept in which data (variables) and methods (functions) are wrapped together inside a single class, and direct access to some data is restricted.
#
# 👉 Simple words me:
# Data ko protect karna aur usko direct access se bachana hi encapsulation hai.
#
# 📌 Why Encapsulation?
#
# Data security
#
# Control over data
#
# Code organization
#
# Prevents accidental modification
#
# in python encapsulation is achived using
# public members
# protected members
# private members

# %%
class Lietcollege:
    _college_library = "Liet library" #protected variable
    __college_accounts = 23456789 #private variable
    college_name = "Liet"#public variable
    
lc=Lietcollege()

# %%
lc._college_library
# Out:
# 'Liet library'

# %%
lc.__college_accounts
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 lc.__college_accounts
#
# AttributeError: 'Lietcollege' object has no attribute '__college_accounts'

# %%
lc.college_name
# Out:
# 'Liet'

# %%
class Lietcollege:
    __account = 23456789 #private variable
    def accountant(self):
        print(self.__account)
lc=Lietcollege()
lc.accountant()
# Out:
# 23456789
