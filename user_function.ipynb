# %%
#calling a function:
def function_name():
    pass
function_name() #function calling

# %%
def add():
    a = 10
    b = 20
    result = a + b
    print(result)
add()
# Out:
# 30

# %%
def function_name():
    pass


def Add():
    pass
# print
# len
# calling a function
def function_name():#def keyword and function_name() is the name of the function
    pass
function_name()#functioncalling

# %%
def add(a,b):
    result= a+b
    print(result)
add(a=110,b=20)
# Out:
# 130

# %% [markdown]
# def add (a,b):
#
#     def used to define a function
#
#     add  function name
#
#     a,b  argument (parameter)

# %%
print()
