# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("You are an adult.")
elif age >= 13:
    print("You are a teenager.")
else:
    print("You are a child.")
# Out:
# You are a child.

# %%
num=int(input("Enter a number: "))
if num/2==0:
    print("Even")   
else: 
    print("Odd")
# Out:
# Odd

# %%
age = 17
if age >= 18:
    print("You are an adult.")
elif age >= 13:
    print("You are a teenager.")
# Out:
# You are a teenager.

# %% [markdown]
# Conditional statement
# A conditional statement is a decision-making statement in programming that allows a program to execute different blocks of code based on whether a condition is true or false.
# <span style="color:red">*In simple words:*</span>
# 👉 It helps the program take decisions.
#
# if age >=18:
#   print("You are eligible to vote")
