# %% [markdown]
# CONSTRUCTORS
# 🔹 Constructor – Definition
#
# Constructor is a special method in a class that is automatically called when an object is created.
# It is mainly used to initialize (assign values to) the data members of a class.
#
# 👉 Simple words me:
# Jab object banta hai, tab constructor automatically run hota hai.
#
# 🎯 Uses of Constructor
#
# Initialize variables
#
# Allocate resources
#
# Set default values
#
# method = __init__()

# %%
class College:
    def __init__(self):###method
        pass

# %%
class College:
    def __init__(self):###method
        print("This is a constructor")
st=College()  #calling constructor
# Out:
# This is a constructor

# %%
class Student:
    def __init__(self,name, marks):
        self.name=name #istance variable
        self.marks=marks
st=Student(name="Rohil",marks=80)
st1=Student(name="monu",marks=40)

# %%
print(st.name,st.marks)
print(st1.name,st1.marks)
# Out:
# Rohil 80
# monu 40

# %%
class Student:
    def __init__(self):
        self.name= "Rohil"#istance variable
        self.marks=80
st =Student()

# %%
class College:
    def __init__(self,collage_name="liet", marks=0):###method
        self.name=collage_name #istance variable
        self.marks=marks
    def show(self):
        print("my collage name is",self.name)
        print("my marks is",self.marks)
st=College(collage_name="liet",marks=80)

# %%
st.show()
# Out:
# my collage name is liet
# my marks is 80

# %%
##task use all in one class encapsulation and constructor and inheritane
