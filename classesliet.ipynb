# %%
class Liet:
    pass

# %%
class Liet: #class name and class is keyword
    college_name = "liet" #class variable
    college_address = "alwar" #class variable
    college_phone_number = 1234567890 #class variable
    pass

# %%
class LietAlwar:
    college_name = "liet" #class variable
    college_address = "alwar" #class variable
    college_phone_number = 1234567890 #class variable
la=LietAlwar()
print(la.college_address)#object creation
print(la.college_name)
print(la.college_phone_number)
# Out:
# alwar
# liet
# 1234567890

# %%
class Liet: #class name and class is keyword
    college_name = "liet" #class variable
    college_address = "alwar" #class variable
    college_phone_number = 1234567890 #class variable
la=LietAlwar()
lala=LietAlwar()

# %%
lala.college_address
# Out:
# 'alwar'

# %%
class Student:
    name = "Rohit"
    def doc(self):
        print("I am a student")
    St = Student()

# %%
class Student:
    student_name = "Rohit"
    def doc(neelesh):
    #     print(f"I am a student {neelesh.student_name}")
     print("my name is",neelesh.student_name)
st = Student()

# %%
st.doc()
# Out:
# my name is Rohit
